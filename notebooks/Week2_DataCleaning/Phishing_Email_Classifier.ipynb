# %%
# Lab: CyberAI Homelab v1.0 (Docker-Compose)
# Date: December 2025

import sys
import subprocess

def install_package(package):
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package, "--no-cache-dir"])
        print(f"{package} installed successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error installing {package}: {e}")

required_packages = [
    "pandas==2.2.3",
    "scikit-learn==1.5.2",
    "nltk==3.8.6"
]

for pkg in required_packages:
    install_package(pkg)

print("\nIf you see this message → your lab is working perfectly!")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 383.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 48.6 kB/s eta 0:00:0000:0100:07
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.1
#     Uninstalling pandas-2.1.1:
#       Successfully uninstalled pandas-2.1.1
# ...
# pandas==2.2.3 installed successfully.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 69.3 kB/s eta 0:00:0000:0100:05
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.1
#     Uninstalling scikit-learn-1.3.1:
#       Successfully uninstalled scikit-learn-1.3.1
# ...
# scikit-learn==1.5.2 installed successfully.
# ERROR: Ignored the following yanked versions: 3.6.4
# ...

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Download necessary NLTK data (run once)
try:
    nltk.data.find('corpora/stopwords')
except nltk.downloader.DownloadError:
    nltk.download('stopwords')
try:
    nltk.data.find('tokenizers/punkt')
except nltk.downloader.DownloadError:
    nltk.download('punkt')

# Synthetic Dataset
data = {
    'text': [
        "Dear customer, your account has been suspended due to suspicious activity. Please click here to verify your details: http://suspicious-link.com/verify",
        "Congratulations! You have won a free iPhone. Claim your prize now by visiting http://fake-prize-site.net/claim",
        "Your order #12345 has been shipped. Track your package here: http://legit-shipping.com/track/12345",
        "Meeting reminder: Project Alpha sync tomorrow at 10 AM in Conference Room B.",
        "URGENT: Your bank account requires immediate verification. Click the link below to avoid closure: http://urgent-bank-verify.org/login",
        "Hi team, please find the attached Q3 sales report. Let me know your feedback.",
        "You have a new message from an unknown sender. View it here: http://secure-message-portal.biz/view",
        "Reminder: Your subscription is expiring soon. Renew now to continue service: http://renew-service.co/subscription",
        "Please review the attached document for the upcoming policy changes.",
        "Your Amazon order confirmation: Item XYZ. Estimated delivery: 2 days. View details: http://amazon-legit.com/order/xyz"
    ],
    'label': [
        1, # Phishing
        1, # Phishing
        0, # Legitimate
        0, # Legitimate
        1, # Phishing
        0, # Legitimate
        1, # Phishing
        1, # Phishing
        0, # Legitimate
        0  # Legitimate
    ]
}

df = pd.DataFrame(data)

print("Dataset created successfully.")
print(df.head())
print("\nIf you see this message → your lab is working perfectly!")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[5], line 9
#       8 try:
# ----> 9     nltk.data.find('corpora/stopwords')
#      10 except nltk.downloader.DownloadError:
#
# File /opt/conda/lib/python3.11/site-packages/nltk/data.py:696, in find(resource_name, paths)
#     695 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 696 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'stopwords' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/stopwords'
#
#   Searched in:
#     - '/home/jovyan/nltk_data'
#     - '/opt/conda/nltk_data'
#     - '/opt/conda/share/nltk_data'
#     - '/opt/conda/lib/nltk_data'
# ...

# %%
# %pip install nltk pandas scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 254.6 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 95.2 kB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.2/800.2 kB 45.4 kB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Download necessary NLTK data (run once)
try:
    nltk.data.find('corpora/stopwords')
except nltk.downloader.DownloadError:
    nltk.download('stopwords')
try:
    nltk.data.find('tokenizers/punkt')
except nltk.downloader.DownloadError:
    nltk.download('punkt')

# Synthetic Dataset
data = {
    'text': [
        "Dear customer, your account has been suspended due to suspicious activity. Please click here to verify your details: http://suspicious-link.com/verify",
        "Congratulations! You have won a free iPhone. Claim your prize now by visiting http://fake-prize-site.net/claim",
        "Your order #12345 has been shipped. Track your package here: http://legit-shipping.com/track/12345",
        "Meeting reminder: Project Alpha sync tomorrow at 10 AM in Conference Room B.",
        "URGENT: Your bank account requires immediate verification. Click the link below to avoid closure: http://urgent-bank-verify.org/login",
        "Hi team, please find the attached Q3 sales report. Let me know your feedback.",
        "You have a new message from an unknown sender. View it here: http://secure-message-portal.biz/view",
        "Reminder: Your subscription is expiring soon. Renew now to continue service: http://renew-service.co/subscription",
        "Please review the attached document for the upcoming policy changes.",
        "Your Amazon order confirmation: Item XYZ. Estimated delivery: 2 days. View details: http://amazon-legit.com/order/xyz"
    ],
    'label': [
        1, # Phishing
        1, # Phishing
        0, # Legitimate
        0, # Legitimate
        1, # Phishing
        0, # Legitimate
        1, # Phishing
        1, # Phishing
        0, # Legitimate
        0  # Legitimate
    ]
}

df = pd.DataFrame(data)

print("Dataset created successfully.")
print(df.head())
print("\nIf you see this message → your lab is working perfectly!")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 9
#       8 try:
# ----> 9     nltk.data.find('corpora/stopwords')
#      10 except nltk.downloader.DownloadError:
#
# File /opt/conda/lib/python3.11/site-packages/nltk/data.py:696, in find(resource_name, paths)
#     695 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 696 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'stopwords' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/stopwords'
#
#   Searched in:
#     - '/home/jovyan/nltk_data'
#     - '/opt/conda/nltk_data'
#     - '/opt/conda/share/nltk_data'
#     - '/opt/conda/lib/nltk_data'
# ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Download necessary NLTK data (run once)
try:
    nltk.data.find('corpora/stopwords')
except nltk.downloader.DownloadError:
    nltk.download('stopwords')
try:
    nltk.data.find('tokenizers/punkt')
except nltk.downloader.DownloadError:
    nltk.download('punkt')

# Synthetic Dataset
data = {
    'text': [
        "Dear customer, your account has been suspended due to suspicious activity. Please click here to verify your details: http://suspicious-link.com/verify",
        "Congratulations! You have won a free iPhone. Claim your prize now by visiting http://fake-prize-site.net/claim",
        "Your order #12345 has been shipped. Track your package here: http://legit-shipping.com/track/12345",
        "Meeting reminder: Project Alpha sync tomorrow at 10 AM in Conference Room B.",
        "URGENT: Your bank account requires immediate verification. Click the link below to avoid closure: http://urgent-bank-verify.org/login",
        "Hi team, please find the attached Q3 sales report. Let me know your feedback.",
        "You have a new message from an unknown sender. View it here: http://secure-message-portal.biz/view",
        "Reminder: Your subscription is expiring soon. Renew now to continue service: http://renew-service.co/subscription",
        "Please review the attached document for the upcoming policy changes.",
        "Your Amazon order confirmation: Item XYZ. Estimated delivery: 2 days. View details: http://amazon-legit.com/order/xyz"
    ],
    'label': [
        1, # Phishing
        1, # Phishing
        0, # Legitimate
        0, # Legitimate
        1, # Phishing
        0, # Legitimate
        1, # Phishing
        1, # Phishing
        0, # Legitimate
        0  # Legitimate
    ]
}

df = pd.DataFrame(data)

print("Dataset created successfully.")
print(df.head())
print("\nIf you see this message → your lab is working perfectly!")
# Out:
# Dataset created successfully.
#                                                 text  label
# 0  Dear customer, your account has been suspended...      1
# 1  Congratulations! You have won a free iPhone. C...      1
# 2  Your order #12345 has been shipped. Track your...      0
# 3  Meeting reminder: Project Alpha sync tomorrow ...      0
# 4  URGENT: Your bank account requires immediate v...      1
#
# If you see this message → your lab is working perfectly!

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Initialize tools
stop_words = set(stopwords.words('english'))
ps = PorterStemmer()

def preprocess_text(text):
    # 1. Lowercase
    text = text.lower()
    # 2. Remove URLs (Very important for phishing data!)
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # 3. Remove punctuation and numbers
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    # 4. Tokenize and Stem
    tokens = text.split()
    processed_tokens = [ps.stem(word) for word in tokens if word not in stop_words]
    return " ".join(processed_tokens)

# Apply to your dataframe
df['processed_text'] = df['text'].apply(preprocess_text)

print("Text preprocessing complete.")
df[['text', 'processed_text']].head()
# Out:
# Text preprocessing complete.
#                                                 text  \
# 0  Dear customer, your account has been suspended...
# 1  Congratulations! You have won a free iPhone. C...
# 2  Your order #12345 has been shipped. Track your...
# 3  Meeting reminder: Project Alpha sync tomorrow ...
# 4  URGENT: Your bank account requires immediate v...
#
#                                       processed_text
# 0  dear custom account suspend due suspici activ ...
# 1             congratul free iphon claim prize visit
# 2                            order ship track packag
# 3  meet remind project alpha sync tomorrow confer...
# 4  urgent bank account requir immedi verif click ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize Vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=5000)

# Create the feature matrix (X) and target labels (y)
X = tfidf_vectorizer.fit_transform(df['processed_text']).toarray()
y = df['label'].values

print(f"TF-IDF feature extraction complete. Shape: {X.shape}")
# Out:
# TF-IDF feature extraction complete. Shape: (10, 69)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 1. Predict on the test set
y_pred = model.predict(X_test)

# 2. Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")

# 3. Display classification report (adding zero_division to handle small datasets)
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Legitimate (0)', 'Phishing (1)'], zero_division=0))

# 4. Display confusion matrix
print("\nConfusion Matrix:")
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)

print("\nInterpretation:")
print("Top Left: True Negatives (Correctly identified Legitimate)")
print("Bottom Right: True Positives (Correctly identified Phishing)")
# Out:
# Model Accuracy: 0.5000
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# Legitimate (0)       0.50      1.00      0.67         1
#   Phishing (1)       0.00      0.00      0.00         1
#
#       accuracy                           0.50         2
#      macro avg       0.25      0.50      0.33         2
#   weighted avg       0.25      0.50      0.33         2
#
#
# Confusion Matrix:
# [[1 0]
#  [1 0]]
#
# Interpretation:
# Top Left: True Negatives (Correctly identified Legitimate)
# Bottom Right: True Positives (Correctly identified Phishing)
